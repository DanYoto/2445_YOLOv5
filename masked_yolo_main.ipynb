# %%
# !git clone https://github.com/DanYoto/YOLOv5_2445  #
# Out:
# Cloning into 'YOLOv5_2445'...
# remote: Enumerating objects: 11319, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 11319 (delta 10), reused 14 (delta 6), pack-reused 11297
# Receiving objects: 100% (11319/11319), 13.41 MiB | 18.82 MiB/s, done.
# Resolving deltas: 100% (7552/7552), done.

# %%
# %cd YOLOv5_2445/
# Out:
# /content/YOLOv5_2445

# %%
# !git checkout masked_yolo
# Out:
# Branch 'masked_yolo' set up to track remote branch 'masked_yolo' from 'origin'.
# Switched to a new branch 'masked_yolo'

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 1.6 MB 46.9 MB/s

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 1138f8f Python-3.8.15 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %%
# RUN THIS CELL OR THE FOLLOWING BUT NOT BOTH OF THEM
#!python pretrain.py --data data/coco128.yaml --cfg yolov5s_decoder.yaml --weights '' --batch 16 --epoch 21 \
#                    --patch_size 32 --mask_ratio 0.5 --show_reconstructed True
# Out:
# pretrain: weights=, cfg=yolov5s_decoder.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=21, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, patch_size=32, mask_ratio=0.5, show_reconstructed=True
# remote: Enumerating objects: 3218, done.
# remote: Counting objects: 100% (1747/1747), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 3218 (delta 1738), reused 1742 (delta 1735), pack-reused 1471
# Receiving objects: 100% (3218/3218), 591.21 KiB | 1.25 MiB/s, done.
# ...

# %%
# !python pretrain.py --data data/coco128.yaml --cfg yolov5s_decoder_less_upsample.yaml --weights '' --batch 16 --epoch 21 \
                    --patch_size 32 --mask_ratio 0.5 --show_reconstructed True
# Out:
# pretrain: weights=, cfg=yolov5s_decoder_less_upsample.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=21, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, patch_size=32, mask_ratio=0.5, show_reconstructed=True
# github: ⚠️ YOLOv5 is out of date by 60 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-247-g1138f8f Python-3.8.15 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# Be careful to have the correct path from the cell above in the weights section!
# /content/YOLOv5_2445/runs/train/exp/weights/best.pt --> correct path if not trained twice or so above!
# !python train.py --data data/coco128.yaml \
                --cfg yolov5s.yaml \
                --weights '/content/YOLOv5_2445/runs/train/exp/weights/best.pt' \
                --batch-size 16 \
                --epoch 40
# Out:
# train: weights=/content/YOLOv5_2445/runs/train/exp2/weights/best.pt, cfg=yolov5s.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 60 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-247-g1138f8f Python-3.8.15 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python test_loading.py

# %%
# !python train.py --data data/coco128.yaml \
                --cfg yolov5s.yaml \
                --weights '/content/YOLOv5_2445/runs/train/exp2/weights/best.pt' \
                --batch-size 16 \
                --epoch 40
# Out:
# train: weights=/content/YOLOv5_2445/runs/train/exp2/weights/best.pt, cfg=yolov5s.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 60 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-247-g1138f8f Python-3.8.15 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
